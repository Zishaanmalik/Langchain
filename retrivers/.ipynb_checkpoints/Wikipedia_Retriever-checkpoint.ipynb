# %%
import os
os.environ['HF_HOME']=r'F:\Langchain\models'

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpointEmbeddings

embedding_model = HuggingFaceEndpointEmbeddings(
    model="sentence-transformers/all-MiniLM-L6-v2"
)

# %% [markdown]
# ## Wikipedia Retriever

# %%
from langchain_community.retrievers import WikipediaRetriever
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11036\2879121110.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.retrievers import WikipediaRetriever

# %%
import wikipedia
import requests

session = requests.Session()
session.headers.update({
    "User-Agent": "ZishaanLangChain/1.0 (https://github.com/Zishaanmalik/Langchain)"
})

wikipedia.wikipedia.requests = session

print(wikipedia.search("India Pakistan geopolitical history"))
# Out:
# ['2025 India–Pakistan conflict', 'India–Pakistan wars and conflicts', 'India–Pakistan war of 1971', 'India–Pakistan war of 1965', 'Afghanistan–India Strategic Partnership Agreement', 'Indian subcontinent', 'Maritime history of Pakistan', 'History of Pakistan (1947–present)', 'India–Iran relations', 'United States aid to Pakistan']

# %%
# Initialize the retriever (optional: set language and top_k)
retriever = WikipediaRetriever(
    top_k_results=3,
    doc_content_chars_max=4000
)

# %%
# Define your query
query = "the geopolitical history of india and pakistan from the perspective of a chinese"

# Get relevant Wikipedia documents
docs = retriever.invoke(query)

# %%
print(f"Retrieved {len(docs)} documents")

for i, doc in enumerate(docs, 1):
    print(f"\n--- Document {i} ---")
    print(doc.page_content[:500])
    print("Metadata:", doc.metadata)
# Out:
# Retrieved 3 documents
#
# --- Document 1 ---
# The India–Pakistan war of 1971, also known as the third Indo-Pakistani war, was a military confrontation between India and Pakistan that occurred during the Bangladesh Liberation War in East Pakistan from 3 December 1971 until the Pakistani capitulation in Dhaka on 16 December 1971.  The war began with Pakistan's Operation Chengiz Khan, consisting of preemptive aerial strikes on eight Indian air stations. The strikes led to India declaring war on Pakistan, marking their entry into the war for Ea
# ...
